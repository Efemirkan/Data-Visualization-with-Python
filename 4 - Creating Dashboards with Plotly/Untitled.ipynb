# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
import numpy as np

# Read the data
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str,
                                   'Year': str})

# %%
df = airline_data[airline_data['Year'] == '2010']
pd.set_option('display.max_columns', 110)
pd.set_option('display.max_rows', 194)
df.head()
# Out:
#     Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 38      291296  2010        3      8          22          7  2010-08-22
# 52     1870601  2010        3      8          31          2  2010-08-31
# 66      335161  2010        1      2          16          2  2010-02-16
# 70      906836  2010        3      7          28          3  2010-07-28
# 76     1041464  2010        1      3          15          1  2010-03-15
#
#    Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 38                DL                     19790                          DL
# 52                AA                     19805                          AA
# 66                WN                     19393                          WN
# 70                B6                     20409                          B6
# 76                EV                     20366                          EV
#
#    Tail_Number  Flight_Number_Reporting_Airline  OriginAirportID  \
# ...

# %%
df_replace = df.loc[:, ['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']]
for column in df_replace.columns:
    df_replace[column].replace(np.nan, df_replace[column].mean(), inplace=True)
# Out:
#        CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay
# 38              NaN           NaN       NaN            NaN                NaN
# 52              NaN           NaN       NaN            NaN                NaN
# 66              1.0           0.0       3.0            0.0               44.0
# 70              NaN           NaN       NaN            NaN                NaN
# 76              NaN           NaN       NaN            NaN                NaN
# ...             ...           ...       ...            ...                ...
# 26864           NaN           NaN       NaN            NaN                NaN
# 26887           0.0           8.0       8.0            0.0                0.0
# 26894           NaN           NaN       NaN            NaN                NaN
# 26981           NaN           NaN       NaN            NaN                NaN
# 26993           NaN           NaN       NaN            NaN                NaN
#
# [950 rows x 5 columns]

# %%
for column in df_check.columns:
    print(df_check[column].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.loc[['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']].replace(np.nan, df.loc[['CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']].mean(), inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
for column in df_check.columns:
    df_check[column].replace(np.nan, df_check[column].mean(), inplace=True)

# %%
for column in df_check.columns:
    print(df_check[column].unique())
# Out:
# [ 18.33333333   1.           0.          18.          13.
#    8.          21.          40.          14.           2.
#   19.          32.           7.          50.          28.
#   12.         183.           5.          26.          66.
#    4.          30.          70.          23.          15.
#  332.          16.          41.           3.          20.
#   27.         194.          38.          48.          44.
#   39.          11.         104.          84.          31.
#   52.          29.          17.          10.         115.
#   25.          42.          62.         175.          73.
#    9.          36.         114.        ]
# [ 1.33333333  0.         37.          2.          3.         33.
#   5.         34.         18.         14.         15.         20.
#   8.        ]
# [ 14.41666667   3.          17.          14.          24.
#    9.          50.          23.          10.          19.
#    0.          46.          25.         129.          28.
# ...
